# %% [markdown]
# # Spark Job with MLRun
# Run a Spark job which reads a csv file and logs the dataset to MLRun database.<br>
# This basic example can use as a schema for more complex workloads using MLRun and Spark.

# %%
# !/User/align_mlrun.sh
# Out:
# Both server & client are aligned (0.6.3).

# %%
# nuclio: ignore
import nuclio
import os

# %% [markdown]
# ## Build MLRun Function

# %%
#!/usr/local/bin/python

import mlrun
from mlrun.datastore import DataItem
from mlrun.execution import MLClientCtx

from subprocess import run

from pyspark.sql import SparkSession
import pyspark.sql.functions as f

# %%
def read_csv(context: MLClientCtx, 
             dataset: DataItem, 
             artifact_path):
    """
    Read csv while using spark job and mlrun - generate serverless function
    --------------------------------------------------------------------------------------------
    Parameters:
                context : MLClientCtx
                          MLRun introduces a concept of a runtime "context", 
                          the code can be set up to get parameters and inputs from the context, 
                          as well as log run outputs, artifacts, tags, and time-series metrics in the context.
                          
                dataset : csv_file
                          csv file which needs to be local (on our machine)
                          the default location will be "/v3io/projects/<file_name> 
                          which can be change by using mlrun.mount_v3io later in the function specs
                          
                artifact_path : String
                          path on which the outout/artifacts of the fucntion will be saved
                
    Returns:
                logged_dataset : mlrun_artifact
                          dataset will be logged into mlrun database as dataset artifact
    ---------------------------------------------------------------------------------------------
    Notes:
    ---------------------------------------------------------------------------------------------
    Examples:
    """
    
    # get csv file location
    location = dataset.local()
    
    # build spark session
    spark = SparkSession.builder.appName("Spark job").getOrCreate()
    
    # read csv
    df = spark.read.load(location, 
                         format="csv", 
                         sep=",", 
                         header="true")
    
    # sample for logging
    df_to_log = df.toPandas()
    
    # log final report
    context.log_dataset("df_sample", 
                        df=df_to_log,
                        format="csv", index=False,
                        artifact_path=artifact_path)
    
    spark.stop()

# %%
# nuclio: end-code

# %% [markdown]
# ## Download iris data-set

# %%
import requests
import shutil

def download_file(url,path):
    local_filename = url.split('/')[-1]
    
    #file_path = path+"/"+local_filename
    with requests.get(url, stream=True) as r:
        with open("/v3io/projects/"+local_filename, 'wb') as f:
            shutil.copyfileobj(r.raw, f)

    return local_filename

url = "https://s3.wasabisys.com/iguazio/data/iris/iris_dataset.csv"

download_file(url,'/v3io/projects')
# Out:
# 'iris_dataset.csv'

# %% [markdown]
# Please don't remove the # nuclio: end-code cell above
# ## Set MLRun Function Specs

# %%
# mlrun will transform the code above (up to nuclio: end-code cell) into serverless function 
# which will run in k8s pods
fn = mlrun.code_to_function(handler="read_csv", kind="remote-spark")

# %%
# add build commands to our docker image with required moduls
fn.spec.build.commands = ['pip install matplotlib pyspark']

# %%
# build and deploy our docker image
fn.with_spark_service(spark_service="spark")
fn.deploy()
# Out:
# > 2021-06-25 15:59:33,706 [info] starting remote build, image: .mlrun/func-default-spark-mlrun-read-csv:latest
# E0625 16:00:17.145011       1 aws_credentials.go:77] while getting AWS credentials NoCredentialProviders: no valid providers in chain. Deprecated.
# 	For verbose messaging see aws.Config.CredentialsChainVerboseErrors
# INFO[0040] Retrieving image manifest datanode-registry.iguazio-platform.app.dev39.lab.iguazeng.com:80/iguazio/shell:3.0_b117_20210510150319
# INFO[0040] Retrieving image manifest datanode-registry.iguazio-platform.app.dev39.lab.iguazeng.com:80/iguazio/shell:3.0_b117_20210510150319
# INFO[0040] Built cross stage deps: map[]
# INFO[0040] Retrieving image manifest datanode-registry.iguazio-platform.app.dev39.lab.iguazeng.com:80/iguazio/shell:3.0_b117_20210510150319
# INFO[0040] Retrieving image manifest datanode-registry.iguazio-platform.app.dev39.lab.iguazeng.com:80/iguazio/shell:3.0_b117_20210510150319
# INFO[0040] Executing 0 build triggers
# INFO[0040] Unpacking rootfs as cmd RUN pip install matplotlib pyspark requires it.
# INFO[0161] RUN pip install matplotlib pyspark
# INFO[0161] Taking snapshot of full filesystem...
# INFO[0201] cmd: /bin/sh
# INFO[0201] args: [-c pip install matplotlib pyspark]
# INFO[0201] util.Lookup returned: &{Uid:1000 Gid:1000 Username:iguazio Name: HomeDir:/igz}
# INFO[0201] performing slow lookup of group ids for iguazio
# INFO[0201] Running: [/bin/sh -c pip install matplotlib pyspark]
# WARNING: The directory '/.cache/pip' or its parent directory is not owned or is not writable by the current user. The cache has been disabled. Check the permissions and owner of that directory. If executing pip with sudo, you may want sudo's -H flag.
# Collecting matplotlib
#   Downloading matplotlib-3.4.2-cp37-cp37m-manylinux1_x86_64.whl (10.3 MB)
# Requirement already satisfied: pyspark in /spark/python (2.4.5)
# Collecting pyparsing>=2.2.1
#   Downloading pyparsing-2.4.7-py2.py3-none-any.whl (67 kB)
# Collecting kiwisolver>=1.0.1
#   Downloading kiwisolver-1.3.1-cp37-cp37m-manylinux1_x86_64.whl (1.1 MB)
# Collecting pillow>=6.2.0
#   Downloading Pillow-8.2.0-cp37-cp37m-manylinux1_x86_64.whl (3.0 MB)
# Collecting cycler>=0.10
#   Downloading cycler-0.10.0-py2.py3-none-any.whl (6.5 kB)
# Collecting numpy>=1.16
#   Downloading numpy-1.21.0-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (15.7 MB)
# Collecting python-dateutil>=2.7
#   Downloading python_dateutil-2.8.1-py2.py3-none-any.whl (227 kB)
# Collecting py4j==0.10.7
#   Downloading py4j-0.10.7-py2.py3-none-any.whl (197 kB)
# Requirement already satisfied: six in /conda/lib/python3.7/site-packages (from cycler>=0.10->matplotlib) (1.12.0)
# Installing collected packages: pyparsing, kiwisolver, pillow, cycler, numpy, python-dateutil, matplotlib, py4j
# Successfully installed cycler-0.10.0 kiwisolver-1.3.1 matplotlib-3.4.2 numpy-1.21.0 pillow-8.2.0 py4j-0.10.7 pyparsing-2.4.7 python-dateutil-2.8.1
# INFO[0214] Taking snapshot of full filesystem...
# INFO[0224] RUN pip install "mlrun[complete]==0.6.3"
# INFO[0224] cmd: /bin/sh
# INFO[0224] args: [-c pip install "mlrun[complete]==0.6.3"]
# INFO[0224] util.Lookup returned: &{Uid:1000 Gid:1000 Username:iguazio Name: HomeDir:/igz}
# INFO[0224] performing slow lookup of group ids for iguazio
# INFO[0224] Running: [/bin/sh -c pip install "mlrun[complete]==0.6.3"]
# WARNING: The directory '/.cache/pip' or its parent directory is not owned or is not writable by the current user. The cache has been disabled. Check the permissions and owner of that directory. If executing pip with sudo, you may want sudo's -H flag.
# Collecting mlrun[complete]==0.6.3
#   Downloading mlrun-0.6.3-py3-none-any.whl (430 kB)
# Collecting sqlalchemy~=1.3
#   Downloading SQLAlchemy-1.4.19-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.5 MB)
# Collecting pyarrow~=1.0
#   Downloading pyarrow-1.0.1-cp37-cp37m-manylinux2014_x86_64.whl (17.3 MB)
# Collecting dask~=2.12
#   Downloading dask-2.30.0-py3-none-any.whl (848 kB)
# Collecting tabulate<=0.8.3,>=0.8.0
#   Downloading tabulate-0.8.3.tar.gz (46 kB)
# Collecting pandas~=1.2; python_version >= "3.7"
#   Downloading pandas-1.2.5-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.whl (9.9 MB)
# Collecting nest-asyncio~=1.0
#   Downloading nest_asyncio-1.5.1-py3-none-any.whl (5.0 kB)
# Collecting humanfriendly~=8.2
#   Downloading humanfriendly-8.2-py2.py3-none-any.whl (86 kB)
# Collecting alembic<1.6.0,~=1.4
#   Downloading alembic-1.5.8-py2.py3-none-any.whl (159 kB)
# Collecting nuclio-jupyter~=0.8.12
#   Downloading nuclio_jupyter-0.8.15-py3-none-any.whl (46 kB)
# Collecting urllib3<1.27,>=1.25.4
#   Downloading urllib3-1.26.6-py2.py3-none-any.whl (138 kB)
# Collecting kfp~=1.0.1
#   Downloading kfp-1.0.4.tar.gz (116 kB)
# Collecting aiohttp~=3.6
#   Downloading aiohttp-3.7.4.post0-cp37-cp37m-manylinux2014_x86_64.whl (1.3 MB)
# Collecting requests~=2.22
#   Downloading requests-2.25.1-py2.py3-none-any.whl (61 kB)
# Collecting v3io~=0.5.0
#   Downloading v3io-0.5.8-py3-none-any.whl (49 kB)
# Collecting v3io-frames~=0.8.5
#   Downloading v3io_frames-0.8.14-py3-none-any.whl (35 kB)
# Collecting storey~=0.4.9; python_version >= "3.7"
#   Downloading storey-0.4.9-py3-none-any.whl (98 kB)
# Collecting cryptography~=3.3.2
#   Downloading cryptography-3.3.2-cp36-abi3-manylinux2010_x86_64.whl (2.6 MB)
# Collecting pyyaml~=5.1
#   Downloading PyYAML-5.4.1-cp37-cp37m-manylinux1_x86_64.whl (636 kB)
# Collecting numpy<1.20.0,>=1.16.5
#   Downloading numpy-1.19.5-cp37-cp37m-manylinux2010_x86_64.whl (14.8 MB)
# Collecting mergedeep~=1.3
#   Downloading mergedeep-1.3.4-py3-none-any.whl (6.4 kB)
# Collecting fastapi~=0.62.0
#   Downloading fastapi-0.62.0-py3-none-any.whl (49 kB)
# Collecting pydantic~=1.5
#   Downloading pydantic-1.8.2-cp37-cp37m-manylinux2014_x86_64.whl (10.1 MB)
# Collecting click~=7.0
#   Downloading click-7.1.2-py2.py3-none-any.whl (82 kB)
# Collecting GitPython~=3.0
#   Downloading GitPython-3.1.18-py3-none-any.whl (170 kB)
# Collecting semver~=2.13
#   Downloading semver-2.13.0-py2.py3-none-any.whl (12 kB)
# Collecting distributed<3,>=2.23
#   Downloading distributed-2.30.1-py3-none-any.whl (656 kB)
# Collecting orjson<3.4,>=3
#   Downloading orjson-3.3.1-cp37-cp37m-manylinux2014_x86_64.whl (208 kB)
# Collecting kubernetes~=11.0
#   Downloading kubernetes-11.0.0-py3-none-any.whl (1.5 MB)
# Collecting fsspec~=0.9.0
#   Downloading fsspec-0.9.0-py3-none-any.whl (107 kB)
# Collecting ipython<7.17,>=5.5
#   Downloading ipython-7.16.1-py3-none-any.whl (785 kB)
# Collecting v3iofs~=0.1.5
#   Downloading v3iofs-0.1.6.tar.gz (16 kB)
# Requirement already satisfied: chardet<4.0,>=3.0.2 in /conda/lib/python3.7/site-packages (from mlrun[complete]==0.6.3) (3.0.4)
# Collecting azure-keyvault-secrets~=4.2; extra == "complete"
#   Downloading azure_keyvault_secrets-4.3.0-py2.py3-none-any.whl (233 kB)
# Collecting azure-storage-blob<12.7.0,~=12.0; extra == "complete"
#   Downloading azure_storage_blob-12.6.0-py2.py3-none-any.whl (328 kB)
# Collecting azure-identity~=1.5; extra == "complete"
#   Downloading azure_identity-1.6.0-py2.py3-none-any.whl (108 kB)
# Collecting botocore<1.20.50,>=1.20.49; extra == "complete"
#   Downloading botocore-1.20.49-py2.py3-none-any.whl (7.4 MB)
# Collecting adlfs~=0.7.1; extra == "complete"
#   Downloading adlfs-0.7.7.tar.gz (37 kB)
# Collecting boto3<1.17.50,~=1.9; extra == "complete"
#   Downloading boto3-1.17.49-py2.py3-none-any.whl (131 kB)
# Collecting s3fs~=0.5.0; extra == "complete"
#   Downloading s3fs-0.5.2-py3-none-any.whl (22 kB)
# Collecting importlib-metadata; python_version < "3.8"
#   Downloading importlib_metadata-4.5.0-py3-none-any.whl (17 kB)
# Collecting greenlet!=0.4.17; python_version >= "3"
#   Downloading greenlet-1.1.0-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (160 kB)
# Requirement already satisfied: python-dateutil>=2.7.3 in /conda/lib/python3.7/site-packages (from pandas~=1.2; python_version >= "3.7"->mlrun[complete]==0.6.3) (2.8.1)
# Collecting pytz>=2017.3
#   Downloading pytz-2021.1-py2.py3-none-any.whl (510 kB)
# Collecting python-editor>=0.3
#   Downloading python_editor-1.0.4-py3-none-any.whl (4.9 kB)
# Collecting Mako
#   Downloading Mako-1.1.4-py2.py3-none-any.whl (75 kB)
# Collecting notebook>=5.2.0
#   Downloading notebook-6.4.0-py3-none-any.whl (9.5 MB)
# Collecting nbconvert>=5.4
#   Downloading nbconvert-6.1.0-py3-none-any.whl (551 kB)
# Collecting google-cloud-storage>=1.13.0
#   Downloading google_cloud_storage-1.39.0-py2.py3-none-any.whl (103 kB)
# Collecting google-auth>=1.6.1
#   Downloading google_auth-1.32.0-py2.py3-none-any.whl (147 kB)
# Collecting requests_toolbelt>=0.8.0
#   Downloading requests_toolbelt-0.9.1-py2.py3-none-any.whl (54 kB)
# Collecting cloudpickle
#   Downloading cloudpickle-1.6.0-py3-none-any.whl (23 kB)
# Collecting kfp-server-api<2.0.0,>=0.2.5
#   Downloading kfp-server-api-1.6.0.tar.gz (52 kB)
# Collecting jsonschema>=3.0.1
#   Downloading jsonschema-3.2.0-py2.py3-none-any.whl (56 kB)
# Collecting Deprecated
#   Downloading Deprecated-1.2.12-py2.py3-none-any.whl (9.5 kB)
# Collecting strip-hints
#   Downloading strip-hints-0.1.9.tar.gz (30 kB)
# Collecting attrs>=17.3.0
#   Downloading attrs-21.2.0-py2.py3-none-any.whl (53 kB)
# Collecting yarl<2.0,>=1.0
#   Downloading yarl-1.6.3-cp37-cp37m-manylinux2014_x86_64.whl (294 kB)
# Collecting typing-extensions>=3.6.5
#   Downloading typing_extensions-3.10.0.0-py3-none-any.whl (26 kB)
# Collecting multidict<7.0,>=4.5
#   Downloading multidict-5.1.0-cp37-cp37m-manylinux2014_x86_64.whl (142 kB)
# Collecting async-timeout<4.0,>=3.0
#   Downloading async_timeout-3.0.1-py3-none-any.whl (8.2 kB)
# Requirement already satisfied: certifi>=2017.4.17 in /conda/lib/python3.7/site-packages (from requests~=2.22->mlrun[complete]==0.6.3) (2020.12.5)
# Requirement already satisfied: idna<3,>=2.5 in /conda/lib/python3.7/site-packages (from requests~=2.22->mlrun[complete]==0.6.3) (2.8)
# Collecting future>=0.18.2
#   Downloading future-0.18.2.tar.gz (829 kB)
# Collecting ujson>=3.0.0
#   Downloading ujson-4.0.2-cp37-cp37m-manylinux1_x86_64.whl (179 kB)
# Collecting grpcio==1.30.0
#   Downloading grpcio-1.30.0-cp37-cp37m-manylinux2010_x86_64.whl (3.0 MB)
# Collecting grpcio-tools==1.30.0
#   Downloading grpcio_tools-1.30.0-cp37-cp37m-manylinux2010_x86_64.whl (2.5 MB)
# Collecting googleapis-common-protos>=1.5.3
#   Downloading googleapis_common_protos-1.53.0-py2.py3-none-any.whl (198 kB)
# Requirement already satisfied: cffi>=1.12 in /conda/lib/python3.7/site-packages (from cryptography~=3.3.2->mlrun[complete]==0.6.3) (1.12.2)
# Requirement already satisfied: six>=1.4.1 in /conda/lib/python3.7/site-packages (from cryptography~=3.3.2->mlrun[complete]==0.6.3) (1.12.0)
# Collecting starlette==0.13.6
#   Downloading starlette-0.13.6-py3-none-any.whl (59 kB)
# Collecting gitdb<5,>=4.0.1
#   Downloading gitdb-4.0.7-py3-none-any.whl (63 kB)
# Requirement already satisfied: setuptools in /conda/lib/python3.7/site-packages (from distributed<3,>=2.23->mlrun[complete]==0.6.3) (41.0.0)
# Collecting tornado>=5; python_version < "3.8"
#   Downloading tornado-6.1-cp37-cp37m-manylinux2010_x86_64.whl (428 kB)
# Collecting zict>=0.1.3
#   Downloading zict-2.0.0-py3-none-any.whl (10 kB)
# Collecting msgpack>=0.6.0
#   Downloading msgpack-1.0.2-cp37-cp37m-manylinux1_x86_64.whl (273 kB)
# Collecting sortedcontainers!=2.0.0,!=2.0.1
#   Downloading sortedcontainers-2.4.0-py2.py3-none-any.whl (29 kB)
# Collecting tblib>=1.6.0
#   Downloading tblib-1.7.0-py2.py3-none-any.whl (12 kB)
# Collecting toolz>=0.8.2
#   Downloading toolz-0.11.1-py3-none-any.whl (55 kB)
# Collecting psutil>=5.0
#   Downloading psutil-5.8.0-cp37-cp37m-manylinux2010_x86_64.whl (296 kB)
# Collecting websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0
#   Downloading websocket_client-1.1.0-py2.py3-none-any.whl (68 kB)
# Collecting requests-oauthlib
#   Downloading requests_oauthlib-1.3.0-py2.py3-none-any.whl (23 kB)
# Collecting jedi>=0.10
#   Downloading jedi-0.18.0-py2.py3-none-any.whl (1.4 MB)
# Collecting decorator
#   Downloading decorator-5.0.9-py3-none-any.whl (8.9 kB)
# Collecting pickleshare
#   Downloading pickleshare-0.7.5-py2.py3-none-any.whl (6.9 kB)
# Collecting pygments
#   Downloading Pygments-2.9.0-py3-none-any.whl (1.0 MB)
# Collecting pexpect; sys_platform != "win32"
#   Downloading pexpect-4.8.0-py2.py3-none-any.whl (59 kB)
# Collecting prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0
#   Downloading prompt_toolkit-3.0.19-py3-none-any.whl (368 kB)
# Collecting traitlets>=4.2
#   Downloading traitlets-5.0.5-py3-none-any.whl (100 kB)
# Collecting backcall
#   Downloading backcall-0.2.0-py2.py3-none-any.whl (11 kB)
# Collecting azure-core<2.0.0,>=1.7.0
#   Downloading azure_core-1.15.0-py2.py3-none-any.whl (138 kB)
# Collecting msrest>=0.6.21
#   Downloading msrest-0.6.21-py2.py3-none-any.whl (85 kB)
# Collecting azure-common~=1.1
#   Downloading azure_common-1.1.27-py2.py3-none-any.whl (12 kB)
# Collecting msal<2.0.0,>=1.7.0
#   Downloading msal-1.12.0-py2.py3-none-any.whl (66 kB)
# Collecting msal-extensions~=0.3.0
#   Downloading msal_extensions-0.3.0-py2.py3-none-any.whl (16 kB)
# Collecting jmespath<1.0.0,>=0.7.1
#   Downloading jmespath-0.10.0-py2.py3-none-any.whl (24 kB)
# Collecting azure-datalake-store<0.1,>=0.0.46
#   Downloading azure_datalake_store-0.0.52-py2.py3-none-any.whl (61 kB)
# Collecting s3transfer<0.4.0,>=0.3.0
#   Downloading s3transfer-0.3.7-py2.py3-none-any.whl (73 kB)
# Collecting aiobotocore>=1.0.1
#   Downloading aiobotocore-1.3.1.tar.gz (48 kB)
# Collecting zipp>=0.5
#   Downloading zipp-3.4.1-py3-none-any.whl (5.2 kB)
# Collecting MarkupSafe>=0.9.2
#   Downloading MarkupSafe-2.0.1-cp37-cp37m-manylinux2010_x86_64.whl (31 kB)
# Collecting pyzmq>=17
#   Downloading pyzmq-22.1.0-cp37-cp37m-manylinux1_x86_64.whl (1.1 MB)
# Collecting nbformat
#   Downloading nbformat-5.1.3-py3-none-any.whl (178 kB)
# Collecting terminado>=0.8.3
#   Downloading terminado-0.10.1-py3-none-any.whl (14 kB)
# Collecting jinja2
#   Downloading Jinja2-3.0.1-py3-none-any.whl (133 kB)
# Collecting Send2Trash>=1.5.0
#   Downloading Send2Trash-1.7.1-py3-none-any.whl (17 kB)
# Collecting ipython-genutils
#   Downloading ipython_genutils-0.2.0-py2.py3-none-any.whl (26 kB)
# Collecting jupyter-core>=4.6.1
#   Downloading jupyter_core-4.7.1-py3-none-any.whl (82 kB)
# Collecting ipykernel
#   Downloading ipykernel-5.5.5-py3-none-any.whl (120 kB)
# Collecting jupyter-client>=5.3.4
#   Downloading jupyter_client-6.1.12-py3-none-any.whl (112 kB)
# Collecting argon2-cffi
#   Downloading argon2_cffi-20.1.0-cp35-abi3-manylinux1_x86_64.whl (97 kB)
# Collecting prometheus-client
#   Downloading prometheus_client-0.11.0-py2.py3-none-any.whl (56 kB)
# Collecting bleach
#   Downloading bleach-3.3.0-py2.py3-none-any.whl (283 kB)
# Collecting testpath
#   Downloading testpath-0.5.0-py3-none-any.whl (84 kB)
# Collecting jupyterlab-pygments
#   Downloading jupyterlab_pygments-0.1.2-py2.py3-none-any.whl (4.6 kB)
# Collecting defusedxml
#   Downloading defusedxml-0.7.1-py2.py3-none-any.whl (25 kB)
# Collecting entrypoints>=0.2.2
#   Downloading entrypoints-0.3-py2.py3-none-any.whl (11 kB)
# Collecting mistune<2,>=0.8.1
#   Downloading mistune-0.8.4-py2.py3-none-any.whl (16 kB)
# Collecting nbclient<0.6.0,>=0.5.0
#   Downloading nbclient-0.5.3-py3-none-any.whl (82 kB)
# Collecting pandocfilters>=1.4.1
#   Downloading pandocfilters-1.4.3.tar.gz (16 kB)
# Collecting google-cloud-core<2.0dev,>=1.4.1
#   Downloading google_cloud_core-1.7.0-py2.py3-none-any.whl (28 kB)
# Collecting google-resumable-media<2.0dev,>=1.3.0
#   Downloading google_resumable_media-1.3.1-py2.py3-none-any.whl (75 kB)
# Collecting rsa<5,>=3.1.4; python_version >= "3.6"
#   Downloading rsa-4.7.2-py3-none-any.whl (34 kB)
# Collecting pyasn1-modules>=0.2.1
#   Downloading pyasn1_modules-0.2.8-py2.py3-none-any.whl (155 kB)
# Collecting cachetools<5.0,>=2.0.0
#   Downloading cachetools-4.2.2-py3-none-any.whl (11 kB)
# Collecting pyrsistent>=0.14.0
#   Downloading pyrsistent-0.17.3.tar.gz (106 kB)
# Collecting wrapt<2,>=1.10
#   Downloading wrapt-1.12.1.tar.gz (27 kB)
# Requirement already satisfied: wheel in /conda/lib/python3.7/site-packages (from strip-hints->kfp~=1.0.1->mlrun[complete]==0.6.3) (0.33.1)
# Collecting protobuf>=3.5.0.post1
#   Downloading protobuf-3.17.3-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.whl (1.0 MB)
# Requirement already satisfied: pycparser in /conda/lib/python3.7/site-packages (from cffi>=1.12->cryptography~=3.3.2->mlrun[complete]==0.6.3) (2.19)
# Collecting smmap<5,>=3.0.1
#   Downloading smmap-4.0.0-py2.py3-none-any.whl (24 kB)
# Collecting heapdict
#   Downloading HeapDict-1.0.1-py3-none-any.whl (3.9 kB)
# Collecting oauthlib>=3.0.0
#   Downloading oauthlib-3.1.1-py2.py3-none-any.whl (146 kB)
# Collecting parso<0.9.0,>=0.8.0
#   Downloading parso-0.8.2-py2.py3-none-any.whl (94 kB)
# Collecting ptyprocess>=0.5
#   Downloading ptyprocess-0.7.0-py2.py3-none-any.whl (13 kB)
# Collecting wcwidth
#   Downloading wcwidth-0.2.5-py2.py3-none-any.whl (30 kB)
# Collecting isodate>=0.6.0
#   Downloading isodate-0.6.0-py2.py3-none-any.whl (45 kB)
# Collecting PyJWT[crypto]<3,>=1.0.0
#   Downloading PyJWT-2.1.0-py3-none-any.whl (16 kB)
# Collecting portalocker~=1.0; platform_system != "Windows"
#   Downloading portalocker-1.7.1-py2.py3-none-any.whl (10 kB)
# Collecting adal>=0.4.2
#   Downloading adal-1.2.7-py2.py3-none-any.whl (55 kB)
# Collecting aioitertools>=0.5.1
#   Downloading aioitertools-0.7.1-py3-none-any.whl (20 kB)
# Collecting packaging
#   Downloading packaging-20.9-py2.py3-none-any.whl (40 kB)
# Collecting webencodings
#   Downloading webencodings-0.5.1-py2.py3-none-any.whl (11 kB)
# Collecting async-generator
#   Downloading async_generator-1.10-py3-none-any.whl (18 kB)
# Collecting google-api-core<2.0.0dev,>=1.21.0
#   Downloading google_api_core-1.30.0-py2.py3-none-any.whl (93 kB)
# Collecting google-crc32c<2.0dev,>=1.0; python_version >= "3.5"
#   Downloading google_crc32c-1.1.2-cp37-cp37m-manylinux2014_x86_64.whl (38 kB)
# Collecting pyasn1>=0.1.3
#   Downloading pyasn1-0.4.8-py2.py3-none-any.whl (77 kB)
# Requirement already satisfied: pyparsing>=2.0.2 in /conda/lib/python3.7/site-packages (from packaging->bleach->nbconvert>=5.4->nuclio-jupyter~=0.8.12->mlrun[complete]==0.6.3) (2.4.7)
# Building wheels for collected packages: tabulate, kfp, v3iofs, adlfs, kfp-server-api, strip-hints, future, aiobotocore, pandocfilters, pyrsistent, wrapt
#   Building wheel for tabulate (setup.py): started
#   Building wheel for tabulate (setup.py): finished with status 'done'
#   Created wheel for tabulate: filename=tabulate-0.8.3-py3-none-any.whl size=23377 sha256=7cbefa1b475a5c29fd6ab8df132b4950d550c1d4e2a670dc551eda34795d6b57
#   Stored in directory: /tmp/pip-ephem-wheel-cache-c14txhtl/wheels/b8/a2/a6/812a8a9735b090913e109133c7c20aaca4cf07e8e18837714f
#   Building wheel for kfp (setup.py): started
#   Building wheel for kfp (setup.py): finished with status 'done'
#   Created wheel for kfp: filename=kfp-1.0.4-py3-none-any.whl size=159872 sha256=b9ee5fbb893043742b6a178fc3a81c55958bc6632f4238f652ca273b62a1729e
#   Stored in directory: /tmp/pip-ephem-wheel-cache-c14txhtl/wheels/65/1c/be/3d7366d2288bf1587e4fe6cd0c1ebdce5e3bada21b70a29e66
#   Building wheel for v3iofs (setup.py): started
#   Building wheel for v3iofs (setup.py): finished with status 'done'
#   Created wheel for v3iofs: filename=v3iofs-0.1.6-py3-none-any.whl size=12297 sha256=3d7dcbb113f496a13e1470b58d597bdf431afb1695cf2aa47a06c12d49d79e99
#   Stored in directory: /tmp/pip-ephem-wheel-cache-c14txhtl/wheels/b0/39/4d/c8f850fd9698770f98e3775d2e42dd33170ff37d4090efb98c
#   Building wheel for adlfs (setup.py): started
#   Building wheel for adlfs (setup.py): finished with status 'done'
#   Created wheel for adlfs: filename=adlfs-0.7.7-py3-none-any.whl size=20770 sha256=5245d9f3af31b3579650d095d21cf6336773fc58c9258b6ec3aff5437e1a7f27
#   Stored in directory: /tmp/pip-ephem-wheel-cache-c14txhtl/wheels/73/6c/41/2e778857ea58d07e2dd87a2e2a1db63ace1d4559ffb00585d6
#   Building wheel for kfp-server-api (setup.py): started
#   Building wheel for kfp-server-api (setup.py): finished with status 'done'
#   Created wheel for kfp-server-api: filename=kfp_server_api-1.6.0-py3-none-any.whl size=92522 sha256=31e9a8941a97bf03f349171da69c3829c5dcac5193afb371f5b3e302a2877344
#   Stored in directory: /tmp/pip-ephem-wheel-cache-c14txhtl/wheels/25/2f/7c/d5c1cbcb535e30c90b88aa5104b1ee14a0ea9313a543bfdf52
#   Building wheel for strip-hints (setup.py): started
#   Building wheel for strip-hints (setup.py): finished with status 'done'
#   Created wheel for strip-hints: filename=strip_hints-0.1.9-py2.py3-none-any.whl size=20993 sha256=3d418e5c6c2655852eb53dd0003af94de994b6e73c19547b5c6fbe3123c9ce82
#   Stored in directory: /tmp/pip-ephem-wheel-cache-c14txhtl/wheels/2d/b8/4e/a3ec111d2db63cec88121bd7c0ab1a123bce3b55dd19dda5c1
#   Building wheel for future (setup.py): started
#   Building wheel for future (setup.py): finished with status 'done'
#   Created wheel for future: filename=future-0.18.2-py3-none-any.whl size=491056 sha256=324ba12377f1704291c89fbbd085451e371a26afd2b78417e875e5ded114792f
#   Stored in directory: /tmp/pip-ephem-wheel-cache-c14txhtl/wheels/56/b0/fe/4410d17b32f1f0c3cf54cdfb2bc04d7b4b8f4ae377e2229ba0
#   Building wheel for aiobotocore (setup.py): started
#   Building wheel for aiobotocore (setup.py): finished with status 'done'
#   Created wheel for aiobotocore: filename=aiobotocore-1.3.1-py3-none-any.whl size=46611 sha256=f39535e0afe86a25267ec8914b3bb06bbcb444b7914300c797c08af8ef07bd5c
#   Stored in directory: /tmp/pip-ephem-wheel-cache-c14txhtl/wheels/7b/12/84/8c6442a63bb52d26c15b84a9a2a74fc7878f997f5a226ed6cf
#   Building wheel for pandocfilters (setup.py): started
#   Building wheel for pandocfilters (setup.py): finished with status 'done'
#   Created wheel for pandocfilters: filename=pandocfilters-1.4.3-py3-none-any.whl size=7992 sha256=2079827a544428b90b3d32129bc0345ace4572f421e9c1f17c45cabe55edc20f
#   Stored in directory: /tmp/pip-ephem-wheel-cache-c14txhtl/wheels/42/81/34/545dc2fbf0e9137811e901108d37fc04650e81d48f97078000
#   Building wheel for pyrsistent (setup.py): started
#   Building wheel for pyrsistent (setup.py): finished with status 'done'
#   Created wheel for pyrsistent: filename=pyrsistent-0.17.3-cp37-cp37m-linux_x86_64.whl size=123647 sha256=c796174b91f08b0af384725fcaee3ea66b292d3607c1e247334824bf1cbac739
#   Stored in directory: /tmp/pip-ephem-wheel-cache-c14txhtl/wheels/a5/52/bf/71258a1d7b3c8cbe1ee53f9314c6f65f20385481eaee573cc5
#   Building wheel for wrapt (setup.py): started
#   Building wheel for wrapt (setup.py): finished with status 'done'
#   Created wheel for wrapt: filename=wrapt-1.12.1-cp37-cp37m-linux_x86_64.whl size=76412 sha256=03505041435618d71c172642e9dc208c35c73671045054166aefd961b2ca4373
#   Stored in directory: /tmp/pip-ephem-wheel-cache-c14txhtl/wheels/62/76/4c/aa25851149f3f6d9785f6c869387ad82b3fd37582fa8147ac6
# Successfully built tabulate kfp v3iofs adlfs kfp-server-api strip-hints future aiobotocore pandocfilters pyrsistent wrapt
# Installing collected packages: typing-extensions, zipp, importlib-metadata, greenlet, sqlalchemy, numpy, pyarrow, pyyaml, dask, tabulate, pytz, pandas, nest-asyncio, humanfriendly, python-editor, MarkupSafe, Mako, alembic, urllib3, requests, pyzmq, ipython-genutils, traitlets, attrs, pyrsistent, jsonschema, jupyter-core, nbformat, ptyprocess, tornado, terminado, jinja2, Send2Trash, packaging, webencodings, bleach, testpath, pygments, jupyterlab-pygments, defusedxml, entrypoints, mistune, async-generator, jupyter-client, nbclient, pandocfilters, nbconvert, parso, jedi, decorator, pickleshare, pexpect, wcwidth, prompt-toolkit, backcall, ipython, ipykernel, argon2-cffi, prometheus-client, notebook, jmespath, botocore, s3transfer, boto3, nuclio-jupyter, pyasn1, rsa, pyasn1-modules, cachetools, google-auth, protobuf, googleapis-common-protos, google-api-core, google-cloud-core, google-crc32c, google-resumable-media, google-cloud-storage, websocket-client, oauthlib, requests-oauthlib, kubernetes, requests-toolbelt, cloudpickle, kfp-server-api, click, wrapt, Deprecated, strip-hints, kfp, multidict, yarl, async-timeout, aiohttp, future, ujson, v3io, grpcio, grpcio-tools, v3io-frames, fsspec, v3iofs, storey, cryptography, mergedeep, starlette, pydantic, fastapi, smmap, gitdb, GitPython, semver, heapdict, zict, msgpack, sortedcontainers, tblib, toolz, psutil, distributed, orjson, azure-core, isodate, msrest, azure-common, azure-keyvault-secrets, azure-storage-blob, PyJWT, msal, portalocker, msal-extensions, azure-identity, adal, azure-datalake-store, adlfs, aioitertools, aiobotocore, s3fs, mlrun
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.21.0
#     Uninstalling numpy-1.21.0:
#       Successfully uninstalled numpy-1.21.0
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 1.24.1
#     Uninstalling urllib3-1.24.1:
#       Successfully uninstalled urllib3-1.24.1
#   Attempting uninstall: requests
#     Found existing installation: requests 2.21.0
#     Uninstalling requests-2.21.0:
#       Successfully uninstalled requests-2.21.0
#   Attempting uninstall: cryptography
#     Found existing installation: cryptography 2.6.1
#     Uninstalling cryptography-2.6.1:
#       Successfully uninstalled cryptography-2.6.1
# ERROR: After October 2020 you may experience errors when installing or updating packages. This is because pip will change the way that it resolves dependency conflicts.
#
# We recommend you use --use-feature=2020-resolver to test your packages with the new resolver before it becomes the default.
#
# google-api-core 1.30.0 requires six>=1.13.0, but you'll have six 1.12.0 which is incompatible.
# Successfully installed Deprecated-1.2.12 GitPython-3.1.18 Mako-1.1.4 MarkupSafe-2.0.1 PyJWT-2.1.0 Send2Trash-1.7.1 adal-1.2.7 adlfs-0.7.7 aiobotocore-1.3.1 aiohttp-3.7.4.post0 aioitertools-0.7.1 alembic-1.5.8 argon2-cffi-20.1.0 async-generator-1.10 async-timeout-3.0.1 attrs-21.2.0 azure-common-1.1.27 azure-core-1.15.0 azure-datalake-store-0.0.52 azure-identity-1.6.0 azure-keyvault-secrets-4.3.0 azure-storage-blob-12.6.0 backcall-0.2.0 bleach-3.3.0 boto3-1.17.49 botocore-1.20.49 cachetools-4.2.2 click-7.1.2 cloudpickle-1.6.0 cryptography-3.3.2 dask-2.30.0 decorator-5.0.9 defusedxml-0.7.1 distributed-2.30.1 entrypoints-0.3 fastapi-0.62.0 fsspec-0.9.0 future-0.18.2 gitdb-4.0.7 google-api-core-1.30.0 google-auth-1.32.0 google-cloud-core-1.7.0 google-cloud-storage-1.39.0 google-crc32c-1.1.2 google-resumable-media-1.3.1 googleapis-common-protos-1.53.0 greenlet-1.1.0 grpcio-1.30.0 grpcio-tools-1.30.0 heapdict-1.0.1 humanfriendly-8.2 importlib-metadata-4.5.0 ipykernel-5.5.5 ipython-7.16.1 ipython-genutils-0.2.0 isodate-0.6.0 jedi-0.18.0 jinja2-3.0.1 jmespath-0.10.0 jsonschema-3.2.0 jupyter-client-6.1.12 jupyter-core-4.7.1 jupyterlab-pygments-0.1.2 kfp-1.0.4 kfp-server-api-1.6.0 kubernetes-11.0.0 mergedeep-1.3.4 mistune-0.8.4 mlrun-0.6.3 msal-1.12.0 msal-extensions-0.3.0 msgpack-1.0.2 msrest-0.6.21 multidict-5.1.0 nbclient-0.5.3 nbconvert-6.1.0 nbformat-5.1.3 nest-asyncio-1.5.1 notebook-6.4.0 nuclio-jupyter-0.8.15 numpy-1.19.5 oauthlib-3.1.1 orjson-3.3.1 packaging-20.9 pandas-1.2.5 pandocfilters-1.4.3 parso-0.8.2 pexpect-4.8.0 pickleshare-0.7.5 portalocker-1.7.1 prometheus-client-0.11.0 prompt-toolkit-3.0.19 protobuf-3.17.3 psutil-5.8.0 ptyprocess-0.7.0 pyarrow-1.0.1 pyasn1-0.4.8 pyasn1-modules-0.2.8 pydantic-1.8.2 pygments-2.9.0 pyrsistent-0.17.3 python-editor-1.0.4 pytz-2021.1 pyyaml-5.4.1 pyzmq-22.1.0 requests-2.25.1 requests-oauthlib-1.3.0 requests-toolbelt-0.9.1 rsa-4.7.2 s3fs-0.5.2 s3transfer-0.3.7 semver-2.13.0 smmap-4.0.0 sortedcontainers-2.4.0 sqlalchemy-1.4.19 starlette-0.13.6 storey-0.4.9 strip-hints-0.1.9 tabulate-0.8.3 tblib-1.7.0 terminado-0.10.1 testpath-0.5.0 toolz-0.11.1 tornado-6.1 traitlets-5.0.5 typing-extensions-3.10.0.0 ujson-4.0.2 urllib3-1.26.6 v3io-0.5.8 v3io-frames-0.8.14 v3iofs-0.1.6 wcwidth-0.2.5 webencodings-0.5.1 websocket-client-1.1.0 wrapt-1.12.1 yarl-1.6.3 zict-2.0.0 zipp-3.4.1
# INFO[0341] Taking snapshot of full filesystem...
# True

# %% [markdown]
# ### Set MLRun and Run Function
# Once running the function get be monitored in MLRun UI, here in the notebook<br>
# And in out functions dashboard.

# %%
# set mlrun api path and arrtifact path for logging
artifact_path = mlrun.set_environment(api_path = 'http://mlrun-api:8080',
                                      artifact_path = os.path.abspath('./'))

# %%
# run our functions with the relevant params
fn.run(inputs={"dataset": "iris_dataset.csv"},
       artifact_path=artifact_path[1])
# Out:
# > 2021-06-25 16:08:11,359 [info] starting run spark-mlrun-read-csv-read_csv uid=0da6e48ad36249498087941bd62d71c8 DB=http://mlrun-api:8080
# > 2021-06-25 16:08:11,528 [info] Job is running in the background, pod: spark-mlrun-read-csv-read-csv-fcnxs
# 21/06/25 16:08:25 WARN util.NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# > 2021-06-25 16:08:39,540 [info] run executed, status=completed
# final state: completed
# <style>
# .dictlist {
#   background-color: #4EC64B;
#   text-align: center;
#   margin: 4px;
#   border-radius: 3px; padding: 0px 3px 1px 3px; display: inline-block;}
# .artifact {
#   cursor: pointer;
#   background-color: #4EC64B;
#   text-align: left;
#   margin: 4px; border-radius: 3px; padding: 0px 3px 1px 3px; display: inline-block;
# }
# div.block.hidden {
#   display: none;
# }
# .clickable {
#   cursor: pointer;
# }
# .ellipsis {
#   display: inline-block;
#   max-width: 60px;
#   white-space: nowrap;
#   overflow: hidden;
#   text-overflow: ellipsis;
# }
# .master-wrapper {
#   display: flex;
#   flex-flow: row nowrap;
#   justify-content: flex-start;
#   align-items: stretch;
# }
# .master-tbl {
#   flex: 3
# }
# .master-wrapper > div {
#   margin: 4px;
#   padding: 10px;
# }
# iframe.fileview {
#   border: 0 none;
#   height: 100%;
#   width: 100%;
#   white-space: pre-wrap;
# }
# .pane-header-title {
#   width: 80%;
#   font-weight: 500;
# }
# .pane-header {
#   line-height: 1;
#   background-color: #4EC64B;
#   padding: 3px;
# }
# .pane-header .close {
#   font-size: 20px;
#   font-weight: 700;
#   float: right;
#   margin-top: -5px;
# }
# .master-wrapper .right-pane {
#   border: 1px inset silver;
#   width: 40%;
#   min-height: 300px;
#   flex: 3
#   min-width: 500px;
# }
# .master-wrapper * {
#   box-sizing: border-box;
# }
# </style><script>
# function copyToClipboard(fld) {
#     if (document.queryCommandSupported && document.queryCommandSupported('copy')) {
#         var textarea = document.createElement('textarea');
#         textarea.textContent = fld.innerHTML;
#         textarea.style.position = 'fixed';
#         document.body.appendChild(textarea);
#         textarea.select();
#
#         try {
#             return document.execCommand('copy'); // Security exception may be thrown by some browsers.
#         } catch (ex) {
#
#         } finally {
#             document.body.removeChild(textarea);
#         }
#     }
# }
# function expandPanel(el) {
#   const panelName = "#" + el.getAttribute('paneName');
#   console.log(el.title);
#
#   document.querySelector(panelName + "-title").innerHTML = el.title
#   iframe = document.querySelector(panelName + "-body");
#
#   const tblcss = `<style> body { font-family: Arial, Helvetica, sans-serif;}
#     #csv { margin-bottom: 15px; }
#     #csv table { border-collapse: collapse;}
#     #csv table td { padding: 4px 8px; border: 1px solid silver;} </style>`;
#
#   function csvToHtmlTable(str) {
#     return '<div id="csv"><table><tr><td>' +  str.replace(/[\n\r]+$/g, '').replace(/[\n\r]+/g, '</td></tr><tr><td>')
#       .replace(/,/g, '</td><td>') + '</td></tr></table></div>';
#   }
#
#   function reqListener () {
#     if (el.title.endsWith(".csv")) {
#       iframe.setAttribute("srcdoc", tblcss + csvToHtmlTable(this.responseText));
#     } else {
#       iframe.setAttribute("srcdoc", this.responseText);
#     }
#     console.log(this.responseText);
#   }
#
#   const oReq = new XMLHttpRequest();
#   oReq.addEventListener("load", reqListener);
#   oReq.open("GET", el.title);
#   oReq.send();
#
#
#   //iframe.src = el.title;
#   const resultPane = document.querySelector(panelName + "-pane");
#   if (resultPane.classList.contains("hidden")) {
#     resultPane.classList.remove("hidden");
#   }
# }
# function closePanel(el) {
#   const panelName = "#" + el.getAttribute('paneName')
#   const resultPane = document.querySelector(panelName + "-pane");
#   if (!resultPane.classList.contains("hidden")) {
#     resultPane.classList.add("hidden");
#   }
# }
#
# </script>
# <div class="master-wrapper">
#   <div class="block master-tbl"><div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>project</th>
#       <th>uid</th>
#       <th>iter</th>
#       <th>start</th>
#       <th>state</th>
#       <th>name</th>
#       <th>labels</th>
#       <th>inputs</th>
#       <th>parameters</th>
#       <th>results</th>
#       <th>artifacts</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>default</td>
#       <td><div title="0da6e48ad36249498087941bd62d71c8"><a href="https://dashboard.default-tenant.app.dev39.lab.iguazeng.com/mlprojects/default/jobs/monitor/0da6e48ad36249498087941bd62d71c8/overview" target="_blank" >...d62d71c8</a></div></td>
#       <td>0</td>
#       <td>Jun 25 16:08:23</td>
#       <td>completed</td>
#       <td>spark-mlrun-read-csv-read_csv</td>
#       <td><div class="dictlist">v3io_user=avia</div><div class="dictlist">kind=remote-spark</div><div class="dictlist">owner=avia</div><div class="dictlist">host=spark-mlrun-read-csv-read-csv-fcnxs</div></td>
#       <td><div class="artifact" onclick="expandPanel(this)" paneName="result6ce74d3b" title="/files/dev/demos/howto/spark/iris_dataset.csv">dataset</div></td>
#       <td></td>
#       <td></td>
#       <td><div class="artifact" onclick="expandPanel(this)" paneName="result6ce74d3b" title="/files/dev/demos/howto/spark/df_sample.csv">df_sample</div></td>
#     </tr>
#   </tbody>
# </table>
# </div></div>
#   <div id="result6ce74d3b-pane" class="right-pane block hidden">
#     <div class="pane-header">
#       <span id="result6ce74d3b-title" class="pane-header-title">Title</span>
#       <span onclick="closePanel(this)" paneName="result6ce74d3b" class="close clickable">&times;</span>
#     </div>
#     <iframe class="fileview" id="result6ce74d3b-body"></iframe>
#   </div>
# </div>
# to track results use .show() or .logs() or in CLI:
# !mlrun get run 0da6e48ad36249498087941bd62d71c8 --project default , !mlrun logs 0da6e48ad36249498087941bd62d71c8 --project default
# > 2021-06-25 16:08:40,402 [info] run executed, status=completed
