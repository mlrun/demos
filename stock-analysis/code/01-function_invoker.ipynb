# %%
# nuclio: ignore
import nuclio

# %%
# nuclio: start-code

# %%
import mlrun
import requests
import time

# %%
def handler(context,endpoint):
    context.logger.info(f"endpoint is : {endpoint}")
    requests.request("GET", endpoint)
    return "Done"

# %%
# nuclio: end-code

# %%
import mlrun
fn = mlrun.code_to_function('my-test',handler = "handler",image = "mlrun/mlrun",kind = 'job')
fn.apply(mlrun.platforms.v3io_cred())
fn.apply(mlrun.mount_v3io())
fn.export('function_invoker.yaml')
# Out:
# > 2021-09-29 10:16:28,420 [info] function spec saved to path: function_invoker.yaml

# %%
fn.run(params = {"endpoint": "http://default-tenant.app.dev8.lab.iguazeng.com:31594"})
# Out:
# > 2021-09-29 10:16:28,428 [info] starting run my-test-handler uid=daaa3f38f9234eb38b9356a8dcdde968 DB=http://mlrun-api:8080
# > 2021-09-29 10:16:28,564 [info] Job is running in the background, pod: my-test-handler-fg4dj
# > 2021-09-29 10:16:33,707 [info] endpoint is : http://default-tenant.app.dev8.lab.iguazeng.com:31594
# > 2021-09-29 10:19:07,961 [info] run executed, status=completed
# final state: completed
# <style>
# .dictlist {
#   background-color: #4EC64B;
#   text-align: center;
#   margin: 4px;
#   border-radius: 3px; padding: 0px 3px 1px 3px; display: inline-block;}
# .artifact {
#   cursor: pointer;
#   background-color: #4EC64B;
#   text-align: left;
#   margin: 4px; border-radius: 3px; padding: 0px 3px 1px 3px; display: inline-block;
# }
# div.block.hidden {
#   display: none;
# }
# .clickable {
#   cursor: pointer;
# }
# .ellipsis {
#   display: inline-block;
#   max-width: 60px;
#   white-space: nowrap;
#   overflow: hidden;
#   text-overflow: ellipsis;
# }
# ...
